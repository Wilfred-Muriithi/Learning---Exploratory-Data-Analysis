# %%
import pandas as pd
import numpy as np
import seaborn as sb
import urllib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/User/OneDrive/Desktop/Lux Academy/Week 1/winequality/winequality/winequality-white.csv',sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.shape
# Out:
# (4898, 12)

# %%
df.quality.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
df.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
#Finding the correlation matrix
corr_matrix = df.corr()
corr_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
#Using Seaborn to Visualize a heatmap
sb.heatmap(corr_matrix,cmap='coolwarm', annot=True ) #Adding annot=True is optional
# Out:
# <AxesSubplot:>

# %%
#using box plot using Seaborn
sb.boxplot(x='citric acid', y='citric acid', data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='citric acid'>

# %%
#Box plot using matplotlib
plt.boxplot(df['citric acid'], labels=['citric acid'])
plt.show()

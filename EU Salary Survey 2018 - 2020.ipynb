# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#Read all the csv files
df1= pd.read_csv('C:/Users/User/OneDrive/Desktop/Lux Academy/Week 1/Assignment/IT Salary Survey EU 2018.csv')
df2= pd.read_csv('C:/Users/User/OneDrive/Desktop/Lux Academy/Week 1/Assignment/IT Salary Survey EU 2019.csv')
df3= pd.read_csv('C:/Users/User/OneDrive/Desktop/Lux Academy/Week 1/Assignment/IT Salary Survey EU 2020.csv')

# %%
#Merging them to 1 csv
merged_df = pd.concat([df1, df2, df3])

# %%
#Saving the merged file
merged_df.to_csv("merged_file1.csv", index=False)

# %%
#Viewing the first five rows of the dataframe
merged_df.head()
# Out:
#              Timestamp   Age Gender     City                       Position  \
# 0  14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1  14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2  14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3  14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4  14/12/2018 12:50:31  39.0      M  München                    UX Designer
#
#    Years of experience Your level  Current Salary  Salary one year ago  \
# 0                 11.0     Senior         77000.0              76200.0
# 1                  8.0     Senior         65000.0              55000.0
# 2                 10.0     Senior         88000.0              73000.0
# 3                  6.0     Senior         78000.0              55000.0
# 4                 10.0     Senior         69000.0              60000.0
#
#    Salary two years ago  ... Years of experience in Germany  \
# ...

# %%
#Viewing the last five rows of the dataframe
merged_df.tail()
# Out:
#                 Timestamp   Age Gender         City Position  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin      NaN
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin      NaN
# 1250  18/01/2021 23:20:35  39.0   Male       Munich      NaN
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken      NaN
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin      NaN
#
#       Years of experience Your level  Current Salary  Salary one year ago  \
# 1248                  NaN        NaN             NaN                  NaN
# 1249                  NaN        NaN             NaN                  NaN
# 1250                  NaN        NaN             NaN                  NaN
# 1251                  NaN        NaN             NaN                  NaN
# 1252                  NaN        NaN             NaN                  NaN
#
#       Salary two years ago  ... Years of experience in Germany  \
# 1248                   NaN  ...                              5
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3009 entries, 0 to 1252
# Data columns (total 42 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                2018 non-null   object
#  1   Age                                                                                                                      2780 non-null   float64
#  2   Gender                                                                                                                   2985 non-null   object
# ...

# %%
#Finding the mean and Standard Deviation
mean_value = merged_df["Current Salary"].mean()
std_value = merged_df["Current Salary"].std()

# %%
print("Mean value: ", mean_value)
# Out:
# Mean value:  68381.76533333333

# %%
print("Standard deviation: ", std_value)
# Out:
# Standard deviation:  21196.30655727135

# %%
#Finding the variance-covariance matrix
cov_matrix =  merged_df.cov(min_periods=2)
print("Variance-covariance Matrix:", cov_matrix)
# Out:
# Variance-covariance Matrix:                                                              Age  \
# Age                                                 2.923490e+01
# Years of experience                                 1.685156e+01
# Current Salary                                      2.688551e+04
# Salary one year ago                                 3.126060e+04
# Salary two years ago                                3.394550e+04
# Yearly brutto salary (without bonus and stocks)     2.918488e+04
# Yearly bonus                                        4.589370e+03
# Yearly stocks                                      -2.509204e+04
# Yearly brutto salary (without bonus and stocks)...  3.069939e+04
# Yearly bonus one year ago. Only answer if stayi...  5.436284e+03
# Yearly stocks one year ago. Only answer if stay... -2.431464e+04
# Number of home office days per month               -3.146534e+00
# 0                                                            NaN
# ...

# %%
#Finding the correlation Matrix
corr_matrix = merged_df.corr()
print("correlation matrix:",corr_matrix)
# Out:
# correlation matrix:                                                          Age  \
# Age                                                 1.000000
# Years of experience                                 0.655773
# Current Salary                                      0.250284
# Salary one year ago                                 0.295843
# Salary two years ago                                0.314234
# Yearly brutto salary (without bonus and stocks)     0.242880
# Yearly bonus                                        0.094084
# Yearly stocks                                      -0.077303
# Yearly brutto salary (without bonus and stocks)...  0.309817
# Yearly bonus one year ago. Only answer if stayi...  0.068533
# Yearly stocks one year ago. Only answer if stay... -0.094412
# Number of home office days per month               -0.037729
# 0                                                        NaN
# Yearly brutto salary (without bonus and stocks)... -0.017259
# ...

# %%
#Using Seaborn to Visualize a heatmap
sb.heatmap(corr_matrix,cmap='coolwarm') #annot=True is optional
# Out:
# <AxesSubplot:>

# %%
#A box plot using Seaborn
sb.boxplot(x='Age', y='Current Salary', data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Current Salary'>
